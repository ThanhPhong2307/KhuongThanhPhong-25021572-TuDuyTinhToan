# %% [markdown]
# Bài 1

# %%
a = int(input())
b = int(input())
print(f"diện tích hình chữ nhật là: {a * b}")
print(f"chu vi hình chữ nhật là: {2 * (a + b)}")
# Out:
# diện tích hình chữ nhật là: 2
# chu vi hình chữ nhật là: 6

# %% [markdown]
# Bài 2

# %%
r = int(input())
#Lấy π = 3.14
print(f"diện tích hình tròn là: {3.14 * r * r}")
print(f"chu vi hình tròn là: {2 * 3.14 * r}")

# %% [markdown]
# Bài 3

# %%
a = int(input())
b = int(input())
c = int(input())
import math
if a + b < c or a + c < b or b + c < a:
    print("khong la ba canh cua mot tam giac")
elif a == b or a == c or b == c:
    print("tam giác cân")
    print("chu vi tam giác là:", a + b + c)
    print("diện tích tam giác là:", math.sqrt((a + b + c) / 2 * ((a + b + c) / 2 - a) * ((a + b + c) / 2 - b) * ((a + b + c) / 2 - c)) ) #Áp dụng định luật Heron
elif a == b == c:
    print("tam giác đều")
    print("chu vi tam giác là:", a + b + c)
    print("diện tích tam giác là:", (math.sqrt(3) / 4) * a * a) #Công thức tính diện tích tam giác đều
elif math.sqrt(a ^ 2 + b ^ 2) == c or math.sqrt(a ^ 2 + c ^ 2) == b or math.sqrt(b ^ 2 + c ^ 2) == a:
    print("tam giác vuông")
    print("chu vi tam giác là:", a + b + c)
    #Công thức tính diện tích tam giác vuông
    if math.sqrt(a ^ 2 + b ^ 2) == c:
        print("diện tích tam giác là:", 0.5 * a * b)
    elif math.sqrt(a ^ 2 + c ^ 2) == b:
        print("diện tích tam giác là:", 0.5 * a * c)
    else:
        print("diện tích tam giác là:", 0.5 * b * c)
else:
    print("tam giác thường")
    print("chu vi tam giác là:", a + b + c)
    print("diện tích tam giác là:", math.sqrt((a + b + c) / 2 * ((a + b + c) / 2 - a) * ((a + b + c) / 2 - b) * ((a + b + c) / 2 - c)) ) #Áp dụng định luật Heron
