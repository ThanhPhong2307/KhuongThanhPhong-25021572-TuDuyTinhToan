# %% [markdown]
# Xếp Loại Học Lực

# %%
n = float(input("Nhập điểm: "))
u = round(n, 1)
if u >= 8.0:
    print("giỏi")
elif u >= 6.5:
    print("Khá")
elif u >= 5.0:
    print("trung bình")
elif u > 10.0:
    print("Làm gì có loại điểm đấy?")
elif u < 0.0:
    print("Điểm âm???")
else:
    print("Yếu")
# Out:
# Yếu
