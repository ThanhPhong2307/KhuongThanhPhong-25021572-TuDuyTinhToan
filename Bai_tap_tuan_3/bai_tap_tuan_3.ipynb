# %% [markdown]
# W3A2

# %%
x = 3
y = 6
print(f"trước khi đổi: x = {x} , y = {y} ")
x , y = y , x
print(f"sau khi đổi: x = {x} , y = {y}")
# Out:
# trước khi đổi: x = 3 , y = 6
# sau khi đổi: x = 6 , y = 3

# %% [markdown]
# W3A3

# %%
x = int(input())
def is_power_of_two(x):
    if x <= 0:
        return False
    return (x & (x-1)) == 0
print(is_power_of_two(x))
# Out:
# True

# %% [markdown]
# W3A4

# %%
m = int(input())
n = int(input())
import math
x = m % n
n = math.floor(x)
print(f"{n}")
# Out:
# 1

# %% [markdown]
# W3A5

# %%
m = int(input())
n = int(input())
import math
x = m % n
n = math.ceil(x)
print(f"{n}")
# Out:
# 1

# %% [markdown]
# W3A6

# %%
x = int(input())
if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# W3A7

# %%
a = int(input())
b = int(input())
if a & b < 0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A8

# %%
a = str(input())
b = str(input())
if a.isupper() or b.isupper():
    print("vui lòng nhập chữ cái thường")
